# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install openpyxl

# %%
forAgeCalcdf = pd.read_excel('ForAgeCalc.xlsx', usecols=['Gilder GS-11'])

# %%
forAgeCalcdf.describe()
# Out:
#        Gilder GS-11
# count    107.000000
# mean    1180.149533
# std      225.560133
# min      606.000000
# 25%     1031.500000
# 50%     1152.000000
# 75%     1293.500000
# max     2490.000000

# %%
# %matplotlib inline

# %%
plt.hist(forAgeCalcdf['Gilder GS-11'], color='green', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('Gilder GS-11')
# Out:
# Text(0.5, 1.0, 'Gilder GS-11')

# %%
forAgeCalcdf2 = pd.read_excel('ForAgeCalc.xlsx', usecols=['RNHW'])

# %%
forAgeCalcdf2.describe()
# Out:
#               RNHW
# count   136.000000
# mean   1157.661765
# std     295.282294
# min     509.000000
# 25%    1023.500000
# 50%    1133.000000
# 75%    1240.250000
# max    2850.000000

# %%
plt.hist(forAgeCalcdf2['RNHW'], color='navy', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('RNHW')
# Out:
# Text(0.5, 1.0, 'RNHW')

# %%
forAgeCalcdf3 = pd.read_excel('ForAgeCalc.xlsx', usecols=['RNHE'])

# %%
forAgeCalcdf3.describe()
# Out:
#               RNHE
# count    98.000000
# mean   1069.051020
# std     267.474341
# min     441.000000
# 25%     920.750000
# 50%    1041.000000
# 75%    1186.000000
# max    2333.000000

# %%
plt.hist(forAgeCalcdf3['RNHE'], color='purple', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('RNHE')
# Out:
# Text(0.5, 1.0, 'RNHE')

# %%
forAgeCalcdf4 = pd.read_excel('ForAgeCalc.xlsx', usecols=['NY14-TAP-22'])

# %%
forAgeCalcdf4.describe()
# Out:
#        NY14-TAP-22
# count   127.000000
# mean   1337.815809
# std     359.121178
# min     953.598530
# 25%    1116.785158
# 50%    1249.947888
# 75%    1441.229672
# max    2721.831686

# %%
plt.hist(forAgeCalcdf4['NY14-TAP-22'], color='red', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('NY14-TAP-22')
# Out:
# Text(0.5, 1.0, 'NY14-TAP-22')

# %%
forAgeCalcdf5 = pd.read_excel('ForAgeCalc.xlsx', usecols=['E79'])

# %%
forAgeCalcdf5.describe()
# Out:
#                E79
# count   120.000000
# mean   1065.941667
# std     351.927688
# min     505.000000
# 25%     857.500000
# 50%    1029.000000
# 75%    1224.750000
# max    2840.000000

# %%
plt.hist(forAgeCalcdf5['E79'], color='brown', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('E79')
# Out:
# Text(0.5, 1.0, 'E79')

# %%
forAgeCalcdf6 = pd.read_excel('ForAgeCalc.xlsx', usecols=['PB'])

# %%
forAgeCalcdf6.describe()
# Out:
#                 PB
# count   104.000000
# mean   1160.298077
# std     216.232924
# min     624.000000
# 25%    1000.750000
# 50%    1153.000000
# 75%    1278.250000
# max    2090.000000

# %%
plt.hist(forAgeCalcdf6['PB'], color='darkorange', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('PB')
# Out:
# Text(0.5, 1.0, 'PB')

# %%
forAgeCalcdf7 = pd.read_excel('ForAgeCalc.xlsx', usecols=['FL3'])

# %%
forAgeCalcdf7.describe()
# Out:
#                FL3
# count   148.000000
# mean   1147.516149
# std     176.063397
# min     575.010000
# 25%    1024.417500
# 50%    1133.540000
# 75%    1281.977500
# max    1556.280000

# %%
plt.hist(forAgeCalcdf7['FL3'], color='teal', edgecolor='white', bins=range(0,3000,100), density=True)
plt.xlabel('Age (Ma)')
plt.title('FL3')
# Out:
# Text(0.5, 1.0, 'FL3')
