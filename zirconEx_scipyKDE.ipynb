# %%
# !pip install scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import gaussian_kde

# %%
# %matplotlib inline

# %%
forAgeCalcdf = pd.read_excel('ForAgeCalc.xlsx', usecols=['Gilder GS-11'])
data = forAgeCalcdf['Gilder GS-11'].dropna()
kde = gaussian_kde(data, bw_method=0.08)
x_vals = np.linspace(0, 3000, 1000)
density = kde(x_vals)
plt.plot(x_vals, density, color='green')
plt.fill_between(x_vals, density, color='green', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('Gilder GS-11')
# Out:
# Text(0.5, 1.0, 'Gilder GS-11')

# %%
forAgeCalcdf2 = pd.read_excel('ForAgeCalc.xlsx', usecols=['RNHW'])
data2 = forAgeCalcdf2['RNHW'].dropna()
kde2 = gaussian_kde(data2, bw_method=0.08)
x_vals2 = np.linspace(0, 3000, 1000)
density2 = kde2(x_vals2)
plt.plot(x_vals2, density2, color='navy')
plt.fill_between(x_vals2, density2, color='navy', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('RNHW')
# Out:
# Text(0.5, 1.0, 'RNHW')

# %%
forAgeCalcdf3 = pd.read_excel('ForAgeCalc.xlsx', usecols=['RNHE'])
data3 = forAgeCalcdf3['RNHE'].dropna()
kde3 = gaussian_kde(data3, bw_method=0.08)
x_vals3 = np.linspace(0, 3000, 1000)
density3 = kde3(x_vals3)
plt.plot(x_vals3, density3, color='purple')
plt.fill_between(x_vals3, density3, color='purple', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('RNHE')
# Out:
# Text(0.5, 1.0, 'RNHE')

# %%
forAgeCalcdf4 = pd.read_excel('ForAgeCalc.xlsx', usecols=['NY14-TAP-22'])
data4 = forAgeCalcdf4['NY14-TAP-22'].dropna()
kde4 = gaussian_kde(data4, bw_method=0.08)
x_vals4 = np.linspace(0, 3000, 1000)
density4 = kde4(x_vals4)
plt.plot(x_vals4, density4, color='red')
plt.fill_between(x_vals4, density4, color='red', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('NY14-TAP-22')
# Out:
# Text(0.5, 1.0, 'NY14-TAP-22')

# %%
forAgeCalcdf5 = pd.read_excel('ForAgeCalc.xlsx', usecols=['E79'])
data5 = forAgeCalcdf5['E79'].dropna()
kde5 = gaussian_kde(data5, bw_method=0.08)
x_vals5 = np.linspace(0, 3000, 1000)
density5 = kde5(x_vals5)
plt.plot(x_vals5, density5, color='brown')
plt.fill_between(x_vals5, density5, color='brown', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('E79')
# Out:
# Text(0.5, 1.0, 'E79')

# %%
forAgeCalcdf6 = pd.read_excel('ForAgeCalc.xlsx', usecols=['PB'])
data6 = forAgeCalcdf6['PB'].dropna()
kde6 = gaussian_kde(data6, bw_method=0.08)
x_vals6 = np.linspace(0, 3000, 1000)
density6 = kde6(x_vals6)
plt.plot(x_vals6, density6, color='darkorange')
plt.fill_between(x_vals6, density6, color='darkorange', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('PB')
# Out:
# Text(0.5, 1.0, 'PB')

# %%
forAgeCalcdf7 = pd.read_excel('ForAgeCalc.xlsx', usecols=['FL3'])
data7 = forAgeCalcdf7['FL3'].dropna()
kde7 = gaussian_kde(data7, bw_method=0.08)
x_vals7 = np.linspace(0, 3000, 1000)
density7 = kde7(x_vals7)
plt.plot(x_vals7, density7, color='teal')
plt.fill_between(x_vals7, density7, color='teal', alpha=0.3)
plt.xlabel('Age (Ma)')
plt.ylabel('Density')
plt.title('FL3')
# Out:
# Text(0.5, 1.0, 'FL3')
